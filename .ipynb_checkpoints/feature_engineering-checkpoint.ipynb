# %%
from pycaret.classification import *
import collections
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
from tqdm import tqdm
import gc
import random
import lightgbm as lgb
import re
from sklearn.metrics import *
from sklearn.model_selection import KFold
import warnings
import pickle as pkl
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## 데이터 삽입

# %%
train_err  = pd.read_csv('data/train_err_data.csv')
# 에러 데이터
# 유저 아이디, 시간, 모델, 펌웨어, 에러타입, 에러코드
train_qual = pd.read_csv('data/train_quality_data.csv')
# 지표 데이터
# 문제 발생 시점으로부터 10분 간격으로 2시간치 수집
# err 데이터와 별개
train_prob = pd.read_csv('data/train_problem_data.csv')
# 라벨 데이터
# 불만콜 여부, 시간

test_err  = pd.read_csv('data/test_err_data.csv')
test_qual = pd.read_csv('data/test_quality_data.csv')

missing_value = pd.Series([43262, train_err.time.mode()[0], train_err.model_nm.mode()[0], train_err.fwver.mode()[0], train_err.errtype.mode()[0], train_err.errcode.mode()[0]], index=test_err.columns)
test_err = test_err.append(missing_value, ignore_index=True)
# 값이 하나도 없는 고객이 있어서 훈련 데이터의 최빈값을 삽입

# %% [markdown]
# ## Feature

# %% [markdown]
# ### 고객별 각 에러 발생 횟수

# %% [markdown]
# * 각 에러 코드를 피쳐로, 횟수를 값으로 가짐

# %%
def count_errcode(data):
    idx_cnt = len(data['user_id'].unique())
    errcode_cnt = 42
    error = np.zeros((idx_cnt, errcode_cnt))
    min_id = min(data['user_id'])
    
    idx_error = data[['user_id','errtype']].values
    for person_idx, err in tqdm(idx_error):
        error[person_idx - min_id, err - 1] += 1
        
    result = pd.DataFrame(data=error, columns = ['err_' + str(i+1) + '_cnt' for i in range(42)]) 
    
    return result

# %% [markdown]
# 빈도가 낮은 에러타입을 제외해봤으나 성능이 매우 떨어짐 : 전부 써야함

# %%
# err_list = list(train_err['errtype'].value_counts(normalize = True)[train_err['errtype'].value_counts(normalize = True).values >= 0.001].index)

# %%
# def count_errcode2(data):
#     idx_cnt = len(data['user_id'].unique())
#     errcode_cnt = 42
#     error = np.zeros((idx_cnt, errcode_cnt))
#     min_id = min(data['user_id'])
    
#     idx_error = data[['user_id','errtype']].values
#     for person_idx, err in tqdm(idx_error):
#         if err in err_list:
#             error[person_idx - min_id, err - 1] += 1
        
#     result = pd.DataFrame(data=error, columns = ['err_' + str(i+1) + '_cnt' for i in range(42)]) 
    
#     for i in result.columns:
#         if sum(result[i]) == 0:
#             result.drop(i, axis=1, inplace=True)
    
#     return result

# %% [markdown]
# ### 3일간 최대 많이 발생한 횟수

# %%
# def scope_errtype(data):
#     scope = 3
#     for i in tqdm(range(len(data['user_id'].unique()))):
#         user_id = i + min(data['user_id'])
#         user_errtype_dict = {i : 0 for i in range(1, 43)}
#         for day in range(20201101, 20201130 - scope):
#             target = train_err2[train_err2['user_id'] == user_id]
#             target = target[target['date'].between(day, day + scope - 1, inclusive = True)]
#             scope_dict = dict(target.errtype.value_counts())

#             for errtype in scope_dict:
#                 user_errtype_dict[errtype] = max(user_errtype_dict[errtype], scope_dict[errtype])

# %%
def scope_errtype(data, scope = 3, option = 'max'):
    tqdm.pandas()
    data2 = data.copy()
    data2['date'] = data['time'].apply(lambda x: int(str(x)[:8]))
    
    errtype_array = np.zeros((len(data2['user_id'].unique()), 30, 42)) # user_id, date, errtype 
    user_id_min = min(data2['user_id'])
    
    def myfunc(x):
        for day in range(x['date'] % 100, min(31, x['date'] % 100 + scope)):
            errtype_array[x['user_id'] - user_id_min, day-1, x['errtype']-1] += 1
    
    data2.progress_apply(myfunc, axis=1)
    
    np.save('custom_data/scope_{}.npy'.format(scope), errtype_array)
    errtype_array_max = errtype_array.max(axis=1)
    errtype_array_min = errtype_array.min(axis=1)
    errtype_array_std = errtype_array.std(axis=1)
    
    if option == 'max': # 최대값만
        return pd.DataFrame(data=errtype_array_max, columns = ['err_' + str(i+1) + '_scope_' + str(scope) + '_max' for i in range(42)])
    elif option == 'min': # 최소값만
        return pd.DataFrame(data=errtype_array_min, columns = ['err_' + str(i+1) + '_scope_' + str(scope) + '_min' for i in range(42)])
    elif option == 'std' : # 표준편차
        return pd.DataFrame(data=errtype_array_std, columns = ['err_' + str(i+1) + '_scope_' + str(scope) + '_std' for i in range(42)])
    elif option == 'all': # 최대값, 최소값, 표준편차
        return pd.concat([pd.DataFrame(data=errtype_array_max, columns = ['err_' + str(i+1) + '_scope_' + str(scope) + '_max' for i in range(42)]), pd.DataFrame(data=errtype_array_min, columns = ['err_' + str(i+1) + '_scope_' + str(scope) + '_min' for i in range(42)]), pd.DataFrame(data=errtype_array_std, columns = ['err_' + str(i+1) + '_scope_' + str(scope) + '_std' for i in range(42)])], axis=1)

# %% [markdown]
# ### 시간당 최대 발생 횟수

# %%
def max_errtype_hour(data):
    tqdm.pandas()
    data2 = data.copy()
    
    user_id_min = min(data2['user_id'])
    errtype_array = np.zeros((len(data2['user_id'].unique()),42))
    
    data2['hour'] = data['time'].apply(lambda x: int(str(x)[:10]))
    data2 = data2.groupby(['user_id', 'hour', 'errtype']).size().reset_index()
    data2 = data2.groupby(['user_id', 'errtype']).max().reset_index()[['user_id', 'errtype', 0]]
    data2.columns = ['user_id', 'errtype', 'max_count']
    
    for idx, x in data2.iterrows():
        errtype_array[x['user_id'] - user_id_min, x['errtype']-1] = x['max_count']
        
    return pd.DataFrame(data = errtype_array, columns = ['err_{}_hour_max'.format(i+1) for i in range(42)])

# %% [markdown]
# ### 일별 상위 퍼센트

# %%
# def avg_errtype_rank(data):
#     tqdm.pandas()
#     data2 = data.copy()

#     user_id_min = min(data2['user_id'])
#     errtype_array = np.zeros((len(data2['user_id'].unique()), 42)) # user_id, date, errtype
    
#     data2['date'] = data['time'].apply(lambda x: int(str(x)[:8]))
#     data2 = data2.groupby(['user_id', 'date', 'errtype']).size().reset_index()
#     data2.columns = ['user_id', 'date', 'errtype', 'count']
#     data2['rank'] = data2.groupby(['errtype', 'date'])['count'].rank(method = 'min', ascending=True)
#     data2 = data2.groupby(['user_id', 'errtype'])['rank'].max().reset_index()
    
#     for idx, x in tqdm(data2.iterrows()):
#         x = x.astype(int)
#         errtype_array[x['user_id'] - user_id_min, x['errtype']-1] = x['rank']
    
#     return pd.DataFrame(data = errtype_array, columns = ['err_{}_rank_avg'.format(i+1) for i in range(42)])

# %%
def sum_errtype_rank(data):
    tqdm.pandas()
    data2 = data.copy()

    user_id_min = min(data2['user_id'])
    errtype_array = np.zeros((len(data2['user_id'].unique()), 42)) # user_id, date, errtype
    
    data2['date'] = data['time'].apply(lambda x: int(str(x)[:8]))
    data2 = data2.groupby(['user_id', 'date', 'errtype']).size().reset_index()
    data2.columns = ['user_id', 'date', 'errtype', 'count']
    data2['rank'] = data2.groupby(['errtype', 'date'])['count'].rank(method = 'min', ascending=True)
    
    for day in tqdm(range(20201101, 20201131)):
        for errtype in range(1, 43):
            data2.loc[(data2['errtype'] == errtype) & (data2['date'] == day), 'rank'] += (15000 - len(data2[(data2['errtype'] == errtype) & (data2['date'] == day)]))

    data2 = data2.groupby(['user_id', 'errtype'])['rank'].sum().reset_index()
    
    for idx, x in tqdm(data2.iterrows()):
        x = x.astype(int)
        errtype_array[x['user_id'] - user_id_min, x['errtype']-1] = x['rank']/15000
    
    return pd.DataFrame(data = errtype_array, columns = ['err_{}_rank_avg'.format(i+1) for i in range(42)])

# %% [markdown]
# ### 합치기

# %%
count_err = count_errcode(train_err)

# %%
scope_3 = scope_errtype(train_err, scope = 3, option = 'all')

# %%
scope_7 = scope_errtype(train_err, scope = 7, option = 'all')

# %%
err_count_hour = max_errtype_hour(train_err)

# %%
err_rank_sum = sum_errtype_rank(train_err)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:41<00:00,  1.37s/it]
# 231039it [00:29, 7958.18it/s]

# %% [markdown]
# ----

# %% [markdown]
# ## 모델링 및 평가

# %%
set_config('seed', 77)

# %%
problem = np.zeros(15000)
problem[train_prob.user_id.unique()-10000] = 1

# %%
train = pd.concat([count_err, scope_3, scope_7, err_count_hour, err_rank], axis=1)
train['problem'] = problem

# %%
for i in train.columns:
    if 'min' in i :
        train.drop(i, axis='columns', inplace=True)
    if 'diff' in i :
        train.drop(i, axis='columns', inplace=True)

# %%
clf = setup(data = train, target = 'problem')
# Out:
# <style  type="text/css" >
# </style><table id="T_65c917e2_649b_11eb_b824_f94ad54e8c19" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row0_col1" class="data row0 col1" >7398</td>
#             </tr>
#             <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row1_col1" class="data row1 col1" >problem</td>
#             </tr>
#             <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row3_col1" class="data row3 col1" >0.0: 0, 1.0: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row4_col1" class="data row4 col1" >(15000, 295)</td>
#             </tr>
#             <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row6_col1" class="data row6 col1" >294</td>
#             </tr>
#             <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row7_col1" class="data row7 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row11_col1" class="data row11 col1" >(10499, 253)</td>
#             </tr>
#             <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row12_col1" class="data row12 col1" >(4501, 253)</td>
#             </tr>
#             <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_65c917e2_649b_11eb_b824_f94ad54e8c19level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_65c917e2_649b_11eb_b824_f94ad54e8c19row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>

# %%
best_5 = compare_models(sort = 'AUC', n_select = 5)
# Out:
# <style  type="text/css" >
#     #T_f907e0ec_649b_11eb_8918_f94ad54e8c19 th {
#           text-align: left;
#     }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row0_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row0_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row0_col7 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row0_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row1_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row1_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row1_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row1_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row1_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row1_col5 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row1_col6 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row1_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row1_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row2_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row2_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row2_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row2_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row2_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row2_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row2_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row2_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row2_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row3_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row3_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row3_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row3_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row3_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row3_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row3_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row3_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row3_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row4_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row4_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row4_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row4_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row4_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row4_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row4_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row4_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row4_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row5_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row5_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row5_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row5_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row5_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row5_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row5_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row5_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_f907e0ec_649b_11eb_8918_f94ad54e8c19row5_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;

# %%
blended = blend_models(estimator_list = best_5, fold = 10, method = 'soft')
# Out:
# <style  type="text/css" >
#     #T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row10_col0 {
#             background:  yellow;
#         }    #T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row10_col1 {
#             background:  yellow;
#         }    #T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row10_col2 {
#             background:  yellow;
#         }    #T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row10_col3 {
#             background:  yellow;
#         }    #T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row10_col4 {
#             background:  yellow;
#         }    #T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row10_col5 {
#             background:  yellow;
#         }    #T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row10_col6 {
#             background:  yellow;
#         }</style><table id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row0_col0" class="data row0 col0" >0.7733</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row0_col1" class="data row0 col1" >0.815</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row0_col2" class="data row0 col2" >0.4855</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row0_col3" class="data row0 col3" >0.7325</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row0_col4" class="data row0 col4" >0.5839</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row0_col5" class="data row0 col5" >0.4368</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row0_col6" class="data row0 col6" >0.4543</td>
#             </tr>
#             <tr>
#                         <th id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row1_col0" class="data row1 col0" >0.8057</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row1_col1" class="data row1 col1" >0.8499</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row1_col2" class="data row1 col2" >0.5378</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row1_col3" class="data row1 col3" >0.8043</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row1_col4" class="data row1 col4" >0.6446</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row1_col5" class="data row1 col5" >0.5181</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row1_col6" class="data row1 col6" >0.5379</td>
#             </tr>
#             <tr>
#                         <th id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row2_col0" class="data row2 col0" >0.781</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row2_col1" class="data row2 col1" >0.8097</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row2_col2" class="data row2 col2" >0.4767</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row2_col3" class="data row2 col3" >0.7664</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row2_col4" class="data row2 col4" >0.5878</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row2_col5" class="data row2 col5" >0.4495</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row2_col6" class="data row2 col6" >0.4729</td>
#             </tr>
#             <tr>
#                         <th id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row3_col0" class="data row3 col0" >0.7952</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row3_col1" class="data row3 col1" >0.8267</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row3_col2" class="data row3 col2" >0.5291</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row3_col3" class="data row3 col3" >0.7745</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row3_col4" class="data row3 col4" >0.6287</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row3_col5" class="data row3 col5" >0.4941</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row3_col6" class="data row3 col6" >0.5112</td>
#             </tr>
#             <tr>
#                         <th id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row4_col0" class="data row4 col0" >0.7914</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row4_col1" class="data row4 col1" >0.8225</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row4_col2" class="data row4 col2" >0.5015</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row4_col3" class="data row4 col3" >0.7818</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row4_col4" class="data row4 col4" >0.611</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row4_col5" class="data row4 col5" >0.4777</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row4_col6" class="data row4 col6" >0.4996</td>
#             </tr>
#             <tr>
#                         <th id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row5_col0" class="data row5 col0" >0.7695</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row5_col1" class="data row5 col1" >0.8105</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row5_col2" class="data row5 col2" >0.4461</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row5_col3" class="data row5 col3" >0.7463</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row5_col4" class="data row5 col4" >0.5584</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row5_col5" class="data row5 col5" >0.4156</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row5_col6" class="data row5 col6" >0.4408</td>
#             </tr>
#             <tr>
#                         <th id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row6_col0" class="data row6 col0" >0.7867</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row6_col1" class="data row6 col1" >0.8123</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row6_col2" class="data row6 col2" >0.4898</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row6_col3" class="data row6 col3" >0.7742</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row6_col4" class="data row6 col4" >0.6</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54e8c19row6_col5" class="data row6 col5" >0.4644</td>
#                         <td id="T_6a3f22a4_649c_11eb_9414_f94ad54

# %%
pred_holdout = predict_model(blended)
# Out:
# <style  type="text/css" >
# </style><table id="T_6aad0c6e_649c_11eb_937f_f94ad54e8c19" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6aad0c6e_649c_11eb_937f_f94ad54e8c19level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6aad0c6e_649c_11eb_937f_f94ad54e8c19row0_col0" class="data row0 col0" >Voting Classifier</td>
#                         <td id="T_6aad0c6e_649c_11eb_937f_f94ad54e8c19row0_col1" class="data row0 col1" >0.7865</td>
#                         <td id="T_6aad0c6e_649c_11eb_937f_f94ad54e8c19row0_col2" class="data row0 col2" >0.834</td>
#                         <td id="T_6aad0c6e_649c_11eb_937f_f94ad54e8c19row0_col3" class="data row0 col3" >0.5172</td>
#                         <td id="T_6aad0c6e_649c_11eb_937f_f94ad54e8c19row0_col4" class="data row0 col4" >0.798</td>
#                         <td id="T_6aad0c6e_649c_11eb_937f_f94ad54e8c19row0_col5" class="data row0 col5" >0.6277</td>
#                         <td id="T_6aad0c6e_649c_11eb_937f_f94ad54e8c19row0_col6" class="data row0 col6" >0.4874</td>
#                         <td id="T_6aad0c6e_649c_11eb_937f_f94ad54e8c19row0_col7" class="data row0 col7" >0.5099</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# | name | min | new_feature | cat | blended_auc |
# |:---:|:-------:|:---:|---|:---:|
# | train | O | O | 0.8246 | 0.8269 |
# | train2 | X | X | 0.812 | 0.829 |
# | train3 | O | X | 0.8109 | 0.8229 |
# | train4 | X | O | 0.8175 | 0.832 |

# %% [markdown]
# | err_rank | cat | blended_auc |
# |:---:|---|:---:|
# | O | 0.8222 | 0.834 |
# | X | 0.8175 | 0.832 |

# %% [markdown]
# ----

# %%
train_scope_3 = scope_errtype(train_err, scope = 3, option = 'all')
train_scope_7 = scope_errtype(train_err, scope = 7, option = 'all')
train_err_count_hour = max_errtype_hour(train_err)
train_err_rank_sum = sum_errtype_rank(train_err)
train_data = pd.concat([train_scope_3, train_scope_7, train_err_count_hour, train_err_rank_sum], axis=1)
train_data.to_csv("custom_data/kio_train_0201.csv", index=False)
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 16554663/16554663 [13:21<00:00, 20665.58it/s]
# 100%|███████████████████████████████████████████████████████████████████| 16554663/16554663 [23:32<00:00, 11721.66it/s]

# %%
test_scope_3 = scope_errtype(test_err, scope = 3, option = 'all')
test_scope_7 = scope_errtype(test_err, scope = 7, option = 'all')
test_err_count_hour = max_errtype_hour(test_err)
test_err_rank_sum = sum_errtype_rank(test_err)
test_data = pd.concat([test_scope_3, test_scope_7, test_err_count_hour, test_err_rank_sum], axis=1)
test_data.to_csv("custom_data/kio_test_0201.csv", index=False)
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 16532649/16532649 [13:14<00:00, 20815.17it/s]
# 100%|███████████████████████████████████████████████████████████████████| 16532649/16532649 [23:47<00:00, 11583.39it/s]
